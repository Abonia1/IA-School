# %%
import requests
r = requests.get('https://store.celio.com'
                )

# %%
r1 = requests.get('https://store.celio.com/vetement-homme/rivoli-club/1074?l=en_GB')

# %%
from bs4 import BeautifulSoup
soup = BeautifulSoup(r.text, 'html.parser')
soup
#results = soup.find_all('li', attrs={'class':'short-desc'})
# Out:
# <!DOCTYPE html>
#
# <!--[if lt IE 7]>      <html class="no-js lt-ie9 lt-ie8 lt-ie7"> <![endif]-->
# <!--[if IE 7]>         <html class="no-js lt-ie9 lt-ie8"> <![endif]-->
# <!--[if gt IE 8]><!-->
# <!--[if IE 8]>         <html class="no-js lt-ie9"> <![endif]-->
# <!--[if IE 9]>         <html class="no-js lt-ie9"><link rel="stylesheet" href="/sites/26/css/IE.css"><![endif]-->
# <html class="no-js" lang="fr-FR" xml:lang="fr-FR" xmlns="http://www.w3.org/1999/xhtml">
# <!--<![endif]-->
# <head>
# <script type="text/javascript">
#             function trackOutboundLink(categorie, action, libelle, url) {
#                 if(typeof ga !== 'undefined')
#                 {
#                     ga('send', 'event', categorie, action, libelle, {'hitCallback':
#                         function () {
#                             document.location = url;
#                         }
#                     });
#                 }
#                 else
# ...

# %%
resultsAdress = soup.find_all('a',attrs={'class':'footer_link'})
resultsAdress
# Out:
# [<a class="footer_link" href="https://store.celio.com/it/regione-veneto/provincia-di-verona/IT3183458/affi" onclick="trackOutboundLink('Store Locator', 'Liens', 'Clics sur Villes à proximité annuaire', 'https://store.celio.com/it/regione-veneto/provincia-di-verona/IT3183458/affi'); return false;" title="Magasins celio Affi">Magasins celio Affi</a>,
#  <a class="footer_link" href="https://store.celio.com/fr/normandie/manche/50002/agneaux" onclick="trackOutboundLink('Store Locator', 'Liens', 'Clics sur Villes à proximité annuaire', 'https://store.celio.com/fr/normandie/manche/50002/agneaux'); return false;" title="Magasins celio Agneaux">Magasins celio Agneaux</a>,
#  <a class="footer_link" href="https://store.celio.com/fr/occitanie/aude/11002/airoux" onclick="trackOutboundLink('Store Locator', 'Liens', 'Clics sur Villes à proximité annuaire', 'https://store.celio.com/fr/occitanie/aude/11002/airoux'); return false;" title="Magasins celio Airoux">Magasins celio Airoux</a>,
# ...

# %%
len(resultsAdress)
# Out:
# 568

# %%
resultsAdress[0:3]
# Out:
# [<a class="footer_link" href="https://store.celio.com/it/regione-veneto/provincia-di-verona/IT3183458/affi" onclick="trackOutboundLink('Store Locator', 'Liens', 'Clics sur Villes à proximité annuaire', 'https://store.celio.com/it/regione-veneto/provincia-di-verona/IT3183458/affi'); return false;" title="Magasins celio Affi">Magasins celio Affi</a>,
#  <a class="footer_link" href="https://store.celio.com/fr/normandie/manche/50002/agneaux" onclick="trackOutboundLink('Store Locator', 'Liens', 'Clics sur Villes à proximité annuaire', 'https://store.celio.com/fr/normandie/manche/50002/agneaux'); return false;" title="Magasins celio Agneaux">Magasins celio Agneaux</a>,
#  <a class="footer_link" href="https://store.celio.com/fr/occitanie/aude/11002/airoux" onclick="trackOutboundLink('Store Locator', 'Liens', 'Clics sur Villes à proximité annuaire', 'https://store.celio.com/fr/occitanie/aude/11002/airoux'); return false;" title="Magasins celio Airoux">Magasins celio Airoux</a>]

# %%
first_result = resultsAdress[0]
first_result
# Out:
# <a class="footer_link" href="https://store.celio.com/it/regione-veneto/provincia-di-verona/IT3183458/affi" onclick="trackOutboundLink('Store Locator', 'Liens', 'Clics sur Villes à proximité annuaire', 'https://store.celio.com/it/regione-veneto/provincia-di-verona/IT3183458/affi'); return false;" title="Magasins celio Affi">Magasins celio Affi</a>

# %%
first_result.contents
# Out:
# ['Magasins celio Affi']

# %%
first_result['href']
# Out:
# 'https://store.celio.com/it/regione-veneto/provincia-di-verona/IT3183458/affi'

# %%
resultsAdress.find('a').contents[0]

# %%
resultsAdress.contents[1]

# %%
records = []
for result in resultsAdress:
    Name =result.contents
    url=result['href']
    #explanation = result.find('a').text[1:-1]
    #url = result.find('a')['href']
    records.append((Name,url))
    
records
# Out:
# [(['Magasins celio Affi'],
#   'https://store.celio.com/it/regione-veneto/provincia-di-verona/IT3183458/affi'),
#  (['Magasins celio Agneaux'],
#   'https://store.celio.com/fr/normandie/manche/50002/agneaux'),
#  (['Magasins celio Airoux'],
#   'https://store.celio.com/fr/occitanie/aude/11002/airoux'),
#  (['Magasins celio Aix-en-Provence'],
#   'https://store.celio.com/fr/provence-alpes-cote-d-azur/bouches-du-rhone/13001/aix-en-provence'),
#  (['Magasins celio Ajaccio'],
#   'https://store.celio.com/fr/corse/corse-du-sud/2A004/ajaccio'),
#  (['Magasins celio Albi'],
#   'https://store.celio.com/fr/occitanie/tarn/81004/albi'),
#  (['Magasins celio Aldaia'],
#   'https://store.celio.com/es/comunidad-valenciana/valencia/ES2522077/aldaia'),
#  (['Magasins celio Alès'],
#   'https://store.celio.com/fr/occitanie/gard/30007/ales'),
#  (['Magasins celio Ambérieu-en-Bugey'],
#   'https://store.celio.com/fr/auvergne-rhone-alpes/ain/1004/amberieu-en-bugey'),
#  (['Magasins celio Amboise'],
# ...

# %%
records = []
for result in resultsAdress:
    Name =result.contents

# %%
import pandas as pd
#df = pd.DataFrame(records, columns=['Name','Adress', 'CodePostal','phone'])
df = pd.DataFrame(records, columns=['Name','url'])

# %%
df.head()
# Out:
#                                Name  \
# 0             [Magasins celio Affi]
# 1          [Magasins celio Agneaux]
# 2           [Magasins celio Airoux]
# 3  [Magasins celio Aix-en-Provence]
# 4          [Magasins celio Ajaccio]
#
#                                                  url
# 0  https://store.celio.com/it/regione-veneto/prov...
# 1  https://store.celio.com/fr/normandie/manche/50...
# 2  https://store.celio.com/fr/occitanie/aude/1100...
# 3  https://store.celio.com/fr/provence-alpes-cote...
# 4  https://store.celio.com/fr/corse/corse-du-sud/...

# %%
print(first_result.find('a'))
# Out:
# None

# %%
#url = resultsAdress.find('a')['href']
#url
records = []
for result in resultsAdress:
    #date = result.find('href').text[0:-1]
    #lie = result.contents[1][1:-2]
    #explanation = result.find('a').text[1:-1]
    url = result.find('a')['href']
    records.append((url))

# %%
results = soup.find_all('p', attrs={'class':'adress-content'})
results
# Out:
# [<p class="adress-content">
#  <span id="infoboxCelioAdresse1"></span>
#  <span id="infoboxCelioAdresse2"></span>
#  <br/>
#  <span id="infoboxCelioCodePostal"></span>
#  <span id="infoboxCelioVille"></span>
#  </p>]

# %%
resultsAdress.contents

# %%
resultsAdress = soup.find_all('p', attrs={'class':'telephone'})
resultsAdress
# Out:
# [<p class="telephone" id="infoboxCelioTelephone"></p>]

# %%
resultsAdress = soup.find_all('p', attrs={'class':'horaires'})
resultsAdress
# Out:
# [<p class="horaires" id="infoboxCelioHoraires"></p>]

# %%
resultsAdress = soup.find_all('p', attrs={'class':'adress-content'})
resultsAdress

# %%
from bs4 import BeautifulSoup
soup = BeautifulSoup(r.text, 'html.parser')

# %%
records = []
for result in results:
    date = result.find('a').text[0:-1] 
    lie = result.contents[1][1:-2]
    explanation = result.find('a').text[1:-1]
    url = result.find('a')['href']
    records.append((date, lie, explanation, url))

import pandas as pd
df = pd.DataFrame(records, columns=['date', 'lie', 'explanation', 'url'])
df['date'] = pd.to_datetime(df['date'])
df.to_csv('trump_lies.csv', index=False, encoding='utf-8')

# %%
soup.find('link').text[1:-1]
# Out:
# ''

# %%
soup
# Out:
# <!DOCTYPE html>
#
# <!--[if lt IE 7]>      <html class="no-js lt-ie9 lt-ie8 lt-ie7"> <![endif]-->
# <!--[if IE 7]>         <html class="no-js lt-ie9 lt-ie8"> <![endif]-->
# <!--[if gt IE 8]><!-->
# <!--[if IE 8]>         <html class="no-js lt-ie9"> <![endif]-->
# <!--[if IE 9]>         <html class="no-js lt-ie9"><link rel="stylesheet" href="/sites/26/css/IE.css"><![endif]-->
# <html class="no-js" lang="en-GB" xml:lang="en-GB" xmlns="http://www.w3.org/1999/xhtml">
# <!--<![endif]-->
# <head>
# <script type="text/javascript">
#             function trackOutboundLink(categorie, action, libelle, url) {
#                 if(typeof ga !== 'undefined')
#                 {
#                     ga('send', 'event', categorie, action, libelle, {'hitCallback':
#                         function () {
#                             document.location = url;
#                         }
#                     });
#                 }
#                 else
# ...

# %%
results = soup.find_all('div',attrs={'class':'StoreList'})
results
# Out:
# [<div class="StoreList" id="main">
#  </div>]

# %%
results
# Out:
# [<p class="telephone" id="infoboxCelioTelephone"></p>]

# %%
records = []
for result in results:
    #date = result.find('strong').text[0:-1] + ', 2017'
    #lie = result.contents[1][1:-2]
    location = result.find('a').text[1:-1]
    url = result.find('a')['href']
    records.append((location, url))

# %%
first_result=results[0]
first_result
# Out:
# <div class="Wrapper">
# <!-- Fil d'arianne -->
# <a class="c-breadcrumbs_item c-breadcrumbs_link" href="http://www.celio.com" onclick="trackOutboundLink('Store Locator', 'Fil d\'ariane', 'Accueil', 'http://www.celio.com'); return false;">
#         Start    </a>
# <span class="c-breadcrumbs_sep"><span class="c-svg-sprites-arrow-r_pb-s"><span class="c-mask"> &gt; </span></span></span>
# <a class="c-breadcrumbs_item c-breadcrumbs_link" href="https://store.celio.com/?l=en_GB" id="LienPageHome" onclick="trackOutboundLink('Store Locator', 'Fil d\'ariane', 'Lien annuaire', 'https://store.celio.com/?l=en_GB'); return false;" title="Men’s suit and shirt | Sales mode men | Stores celio">
#         celio stores    </a>
# <script type="application/ld+json">
#     {
#         "@context": "https://schema.org",
#         "@type": "BreadcrumbList",
#         "itemListElement": [
#                 {
#             "@type": "ListItem",
#             "position": 1,
#             "name": "Start",
# ...

# %%
href=soup.find_all('p')
href
# Out:
# [<p class="c-header_logo">
#  <a href="https://www.celio.com/">
#  <img alt="Celio - Page d'accueil" height="38" src="/sites/26/img/logo-celio-bl.png" width="135"/>
#  </a>
#  </p>, <p class="adress-content">
#  <span id="infoboxCelioAdresse1"></span>
#  <span id="infoboxCelioAdresse2"></span>
#  <br/>
#  <span id="infoboxCelioCodePostal"></span>
#  <span id="infoboxCelioVille"></span>
#  </p>, <p class="telephone" id="infoboxCelioTelephone"></p>, <p class="horaires" id="infoboxCelioHoraires"></p>, <p class="c-footer_tools_copyright">celio ©2019</p>]
