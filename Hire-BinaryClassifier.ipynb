# %%
import sklearn
from sklearn import datasets
from sklearn.model_selection import train_test_split
import pandas as pd

from sklearn.metrics import classification_report, confusion_matrix, accuracy_score
from sklearn.pipeline import Pipeline
from sklearn import tree
from sklearn.linear_model import LogisticRegression



import matplotlib.pyplot as plt
plt.style.use('classic')
# %matplotlib inline

# %%
#docs_to_train = sklearn.datasets.load_files("statistiques_descriptives_données.csv") 
train = pd.read_csv("statistiques_descriptives_données.csv", engine='python')
train.head()
# Out:
#    Unnamed: 0  index        date cheveux   age   exp  salaire sexe  diplome  \
# 0           0      0  2012-06-02    roux  25.0   9.0  26803.0    F  licence
# 1           1      1  2011-04-21   blond  35.0  13.0  38166.0    M  licence
# 2           2      2  2012-09-07   blond  29.0  13.0  35207.0    M  licence
# 3           3      3  2011-07-01    brun   NaN  12.0  32442.0    M  licence
# 4           4      4  2012-08-07    roux  35.0   6.0  28533.0    F  licence
#
#   specialite   note dispo  embauche
# 0   geologie  97.08   non         0
# 1     forage  63.86   non         0
# 2   geologie  78.50   non         0
# 3   geologie  45.09   non         0
# 4  detective  81.91   non         0

# %%
#df = pd.DataFrame(['non'], columns=['dispo'])

print(train.dispo.str.count("non").sum())
print(train.dispo.str.count("oui").sum())
data=pd.DataFrame(train,columns=['age'])
print(data)
# Out:
# 11848.0
# 8046.0
#         age
# 0      25.0
# 1      35.0
# 2      29.0
# 3       NaN
# 4      35.0
# 5      37.0
# 6      33.0
# 7      31.0
# 8      43.0
# 9      28.0
# 10     50.0
# 11     43.0
# 12     44.0
# 13     39.0
# 14     23.0
# 15     38.0
# 16     31.0
# 17     37.0
# 18     35.0
# 19     44.0
# 20     31.0
# 21     30.0
# 22     39.0
# 23     31.0
# 24     35.0
# 25     31.0
# 26     33.0
# 27     42.0
# 28     27.0
# 29     19.0
# ...     ...
# 19970  25.0
# 19971  44.0
# 19972  27.0
# 19973  33.0
# 19974  33.0
# 19975  27.0
# 19976  50.0
# 19977  42.0
# 19978  38.0
# 19979  20.0
# 19980  24.0
# 19981  35.0
# 19982  43.0
# 19983  51.0
# 19984  50.0
# 19985  42.0
# 19986  38.0
# 19987  39.0
# 19988  40.0
# 19989  25.0
# 19990  32.0
# 19991  33.0
# 19992  28.0
# 19993  35.0
# 19994  33.0
# 19995  47.0
# 19996  38.0
# 19997  23.0
# 19998  33.0
# 19999  35.0
#
# [20000 rows x 1 columns]

# %%
import seaborn as sns
import numpy as np


#data = np.random.multivariate_normal([0, 0], [[5, 2], [2, 2]], size=2000)
data = pd.DataFrame(train, columns=['age', 'embauche'])

for col in 'ageembauche':
    plt.hist(data[col], normed=True, alpha=0.5)


sns.lmplot('age', 'embauche', data=df, fit_reg=False)

# %%
import seaborn as sns
sns.set(style="ticks", color_codes=True)

iris = sns.load_dataset("iris", encoding="utf-8")

g = sns.pairplot(iris)

# %%
sns.barplot(x=train.age,y=train.embauche)

# %%
import matplotlib.pyplot as plt
plt.figure()
sns.pairplot(data=train, hue="age", dropna=True)

# %%
#Split data for train and test set
X_train, X_test, y_train, y_test = train_test_split(train.data,
    train.target, test_size=0.3,random_state=42)

# %%
feature=train.iloc[:,:-1]
labels=pd.DataFrame(train,columns=['embauche'])

# %%
feature = feature.apply(pd.to_numeric, errors='coerce')
labels = labels.apply(pd.to_numeric, errors='coerce')

# %%
# Split our data
train, test, train_labels, test_labels = train_test_split(feature,
                                                          labels,
                                                          test_size=0.33,
                                                          random_state=42)

# %%
feature
labels
# Out:
#        embauche
# 7070          0
# 13010         0
# 6688          0
# 9976          1
# 5175          0
# 19353         0
# 13415         0
# 3087          0
# 16578         0
# 17174         0
# 19607         0
# 3187          0
# 16881         0
# 2030          0
# 7486          0
# 245           0
# 17090         0
# 15105         0
# 19568         0
# 15764         0
# 14873         0
# 10936         0
# 15580         0
# 10352         1
# 18270         0
# 15062         1
# 3736          0
# 16444         0
# 8088          0
# 17570         0
# ...         ...
# 1267          0
# 1899          0
# 3005          0
# 19118         0
# 189           0
# 2747          0
# 18431         0
# 18942         0
# 8666          0
# 6396          0
# 19769         0
# 17568         0
# 6420          0
# 5051          0
# 5311          0
# 2433          0
# 769           0
# 1685          1
# 8322          0
# 16023         0
# 11363         0
# 14423         1
# 4426          0
# ...

# %%
# all parameters not specified are set to their defaults
logisticRegr = LogisticRegression()

# %%
logisticRegr.fit(train,train_labels)

# %%
# Returns a NumPy Array
# Predict for One Observation (image)
logisticRegr.predict(x_test[0].reshape(1,-1))

# %%
#Fit train data with classifier
Classifier.fit(X_train, y_train)

# %%
#Predict test data using classifier
predicted = Neo_Classifier.predict(X_test)

# %%
#Import metrics method to calculate accuray score and better insight report

from sklearn import metrics

#computing precision,recall,f1score and accuracy
#To avoid difference in numbers of labels and classes try to specify the number of labels.Labels are category with array index.

print(metrics.classification_report(y_test, predicted))
