# %%
# %matplotlib inline
import pandas as pd

import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
listings = pd.read_csv('C:/Users/ABONIA/Downloads/listings.csv.gz', compression='gzip')
# Out:
# C:\Users\ABONIA\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:2785: DtypeWarning: Columns (43,61,62) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
listings.head()
# Out:
#      id                        listing_url       scrape_id last_scraped  \
# 0  3109  https://www.airbnb.com/rooms/3109  20200216042459   2020-02-16
# 1  5396  https://www.airbnb.com/rooms/5396  20200216042459   2020-02-17
# 2  7397  https://www.airbnb.com/rooms/7397  20200216042459   2020-02-16
# 3  7964  https://www.airbnb.com/rooms/7964  20200216042459   2020-02-16
# 4  9359  https://www.airbnb.com/rooms/9359  20200216042459   2020-02-16
#
#                                               name  \
# 0                                     zen and calm
# 1                   Explore the heart of old Paris
# 2                 MARAIS - 2ROOMS APT - 2/4 PEOPLE
# 3                Large & sunny flat with balcony !
# 4  Cozy, Central Paris: WALK or VELIB EVERYWHERE !
#
#                                              summary  \
# 0  Appartement très calme de 50M2 Utilisation de ...
# 1  Cozy, well-appointed and graciously designed s...
# 2          VERY CONVENIENT, WITH THE BEST LOCATION !
# 3  Very large & nice apartment all for you!  - Su...
# 4  Location! Location! Location! Just bring your ...
#
#                                                space  \
# 0                   I bedroom appartment in Paris 14
# 1  Small, well appointed studio apartment at the ...
# 2  PLEASE ASK ME BEFORE TO MAKE A REQUEST !!! No ...
# 3  hello ! We have a great 75 square meter apartm...
# 4  Since I live in the USA, it is difficult to ma...
#
#                                          description experiences_offered  \
# 0  I bedroom appartment in Paris 14 Good restaura...                none
# 1  Cozy, well-appointed and graciously designed s...                none
# 2  VERY CONVENIENT, WITH THE BEST LOCATION ! PLEA...                none
# 3  Very large & nice apartment all for you!  - Su...                none
# 4  Location! Location! Location! Just bring your ...                none
#
#                                neighborhood_overview  ... instant_bookable  \
# 0  Good restaurants very close the Montparnasse S...  ...                f
# 1  You are within walking distance to the Louvre,...  ...                t
# 2                                                NaN  ...                f
# 3                                                NaN  ...                f
# 4                                                NaN  ...                f
#
#   is_business_travel_ready          cancellation_policy  \
# 0                        f                     flexible
# 1                        f  strict_14_with_grace_period
# 2                        f                     moderate
# 3                        f  strict_14_with_grace_period
# 4                        f  strict_14_with_grace_period
#
#   require_guest_profile_picture require_guest_phone_verification  \
# 0                             f                                f
# 1                             f                                f
# 2                             f                                f
# 3                             f                                f
# 4                             t                                t
#
#    calculated_host_listings_count  \
# 0                               1
# 1                               1
# 2                               1
# 3                               1
# 4                               1
#
#    calculated_host_listings_count_entire_homes  \
# 0                                            1
# 1                                            1
# 2                                            1
# 3                                            1
# 4                                            1
#
#   calculated_host_listings_count_private_rooms  \
# 0                                            0
# 1                                            0
# 2                                            0
# 3                                            0
# 4                                            0
#
#    calculated_host_listings_count_shared_rooms  reviews_per_month
# 0                                            0               0.24
# 1                                            0               1.63
# 2                                            0               2.47
# 3                                            0               0.05
# 4                                            0                NaN
#
# [5 rows x 106 columns]

# %%
listings['name']
# Out:
# 0                                             zen and calm
# 1                           Explore the heart of old Paris
# 2                         MARAIS - 2ROOMS APT - 2/4 PEOPLE
# 3                        Large & sunny flat with balcony !
# 4          Cozy, Central Paris: WALK or VELIB EVERYWHERE !
# 5                                Paris petit coin douillet
# 6                                      Montmartre Studio 7
# 7                                     Montmartre Studio 10
# 8                      Calm  place in a "bourgeois" area !
# 9                                     QUARTIER LATIN APART
# 10                                          DOWNTOWN PARIS
# 11                        Elegant appartment in Montmartre
# 12                             Loft very charming in Paris
# 13                                   Swishy Cosy Paris Pad
# 14                     Faubourg Saint Antoine-chambrecalme
# 15            De Place Voltaire à Chemin vert. Paris 11ème
# 16                       Bedroom & Terrace, Heart of Paris
# 17                     Charming sunny 2BR in Montmartre !
# 18                                Lovely Studio Montmartre
# 19                        Spacious, Light-Filled Apartment
# 20                                 ***ROOFTOP LE MARAIS***
# 21                                     Luxury in St Michel
# 22                       Your Loft / One of a kind / Paris
# 23                     BEAUTIFUL APT IN PARIS CANAL ST MAR
# 24                     Big Flat in Paris with a retro feel
# 25                              A Room in Paris 9e Pigalle
# 26                                 Center of paris: Louvre
# 27                   Cosy 2 rooms appartment in Montmartre
# 28                        LOVELY STUDIO+BALCONY MONTMARTRE
# 29                       LOVELY  APARTMENT NEAR MONTMARTRE
#                                ...
# 66384     Bright room in apartment at 15ème arrondissement
# 66385         Appartement au cœur du village de Montmartre
# 66386                                    Petit studio cosy
# 66387                          Studio lumineux dans le 11E
# 66388                                 Cosy flat in the 9th
# 66389             Appartement 1 chambre limite paris 13ème
# 66390    Cosy and Spacious 1 bedroom located near Villiers
# 66391                  Appartement 4 personnes Paris 18ème
# 66392          Stalingrad地铁站1分钟métro2/5/7 0层迷你超干净小公寓,有cave
# 66393          Cute Parisian apartment in up & coming area
# 66394              ❤️Comfy flat Luxembourg / Notre Dame ❤️
# 66395      Jolie appartement proche métro Saint Mandé (L1)
# 66396    studio très calme Paris centre,  équipé tt con...
# 66397     Appartement de charme avec 2 chambres dans le Ve
# 66398                     BRIGHT AND QUIET STUDIO IN PARIS
# 66399                                        bel appart 4P
# 66400     Charmant, grand et confortable 2 pièces Paris 18
# 66401      Appartement moderne Paris 19ème/Buttes Chaumont
# 66402                 Private Room in the Heart of the 7th
# 66403       Logement entièrement équipé et très bien situé
# 66404                              Grand T2 à Paris 20 eme
# 66405     2 pièces Montmartre Sacré-Cœur / Vue d’exception
# 66406                           studio vue sur tour eiffel
# 66407    Sunny and Cosy studio near Montmartre and Pigalle
# 66408                   Studio Paris Tour Eiffel rue Javel
# 66409    ❃ Pretty T2 - 4 persons - Parc des Buttes-Chau...
# 66410                  ❃ Charming T2 - 2 persons - PARIS ❃
# 66411                                                  NaN
# 66412    What A View : See The Invalides From Your Couch !
# 66413           Appartement calme en plein centre de paris
# Name: name, Length: 66414, dtype: object

# %%
reviews=pd.read_csv("C:/Users/ABONIA/Downloads/reviews.csv")
neighbourhoods=pd.read_csv("C:/Users/ABONIA/Downloads/neighbourhoods.csv")

# %%
#Getting number of listing by neighbourhood
neighbour_listings = listings[['id','neighbourhood']].groupby('neighbourhood').count().round().sort_values(by='id', ascending=False)
neighbour_listings.reset_index(0, inplace=True)
print(neighbour_listings.head())


plt.figure(figsize=(15,12))
sns.barplot(x=neighbour_listings['id'], y=neighbour_listings['neighbourhood'], palette="rocket")
plt.xlabel('Number of listings_id ', fontsize=15)
plt.ylabel('Neighbourhood ', fontsize=15)
plt.title("Number of listings by neighbourhood", fontsize=20)
plt.xticks(rotation= 45)
plt.tight_layout()
# Out:
#           neighbourhood    id
# 0  XVIII Arrondissement  3801
# 1     XI Arrondissement  3376
# 2     XV Arrondissement  2728
# 3      X Arrondissement  2552
# 4   XVII Arrondissement  2399

# %%
propertyType_listings = listings[['id','property_type']].groupby('property_type').count().round().sort_values(by='id', ascending=False)
propertyType_listings.reset_index(0, inplace=True)
propertyType_listings.head()

roomType_listings = listings[['id','room_type']].groupby('room_type').count().round().sort_values(by='id', ascending=False)
roomType_listings.reset_index(0, inplace=True)
roomType_listings.head()

pd.concat([propertyType_listings,roomType_listings],axis=1)
# Out:
#          property_type     id        room_type       id
# 0            Apartment  59634  Entire home/apt  57402.0
# 1          Condominium   2133     Private room   7056.0
# 2       Boutique hotel   1398       Hotel room   1526.0
# 3                 Loft   1209      Shared room    430.0
# 4                House    482              NaN      NaN
# 5   Serviced apartment    441              NaN      NaN
# 6            Townhouse    249              NaN      NaN
# 7                Hotel    237              NaN      NaN
# 8    Bed and breakfast    184              NaN      NaN
# 9                Other    104              NaN      NaN
# 10          Guesthouse     93              NaN      NaN
# 11              Hostel     72              NaN      NaN
# 12         Guest suite     46              NaN      NaN
# 13          Aparthotel     31              NaN      NaN
# 14          Tiny house     30              NaN      NaN
# 15               Villa     19              NaN      NaN
# 16                Boat     16              NaN      NaN
# 17           Houseboat     13              NaN      NaN
# 18                Cave      3              NaN      NaN
# 19            Bungalow      3              NaN      NaN
# 20          Dome house      2              NaN      NaN
# 21             Cottage      2              NaN      NaN
# 22           Camper/RV      2              NaN      NaN
# 23               Cabin      2              NaN      NaN
# 24                Barn      2              NaN      NaN
# 25           Farm stay      2              NaN      NaN
# 26         Earth house      1              NaN      NaN
# 27                Dorm      1              NaN      NaN
# 28               Igloo      1              NaN      NaN
# 29              Island      1              NaN      NaN
# 30        Nature lodge      1              NaN      NaN

# %%
propertyType_listings = listings[['id','property_type']].groupby('property_type').mean().round().sort_values(by='id', ascending=False)
propertyType_listings.reset_index(0, inplace=True)
print(propertyType_listings.head())


plt.figure(figsize=(10,8))
sns.barplot(x= propertyType_listings['id'], y=propertyType_listings['property_type'], palette="rocket")
plt.xlabel('Number of listings', fontsize=15)
plt.ylabel('Property Type ', fontsize=15)
plt.title("Property type in Paris", fontsize=20)
plt.xticks(rotation= 90)
plt.tight_layout()

# %%
listings['room_type'].value_counts()
# Out:
# Entire home/apt    57402
# Private room        7056
# Hotel room          1526
# Shared room          430
# Name: room_type, dtype: int64

# %%
typepivot = listings.pivot_table(index="property_type", columns=["room_type"], values="id",aggfunc='count')
typepivot
# Out:
# room_type           Entire home/apt  Hotel room  Private room  Shared room
# property_type
# Aparthotel                      7.0        20.0           4.0          NaN
# Apartment                   53539.0         NaN        5762.0        333.0
# Barn                            2.0         NaN           NaN          NaN
# Bed and breakfast               2.0        32.0         146.0          4.0
# Boat                            8.0         NaN           8.0          NaN
# Boutique hotel                  4.0      1119.0         274.0          1.0
# Bungalow                        3.0         NaN           NaN          NaN
# Cabin                           NaN         NaN           1.0          1.0
# Camper/RV                       1.0         NaN           1.0          NaN
# Cave                            3.0         NaN           NaN          NaN
# Condominium                  1788.0         NaN         299.0         46.0
# Cottage                         2.0         NaN           NaN          NaN
# Dome house                      2.0         NaN           NaN          NaN
# Dorm                            1.0         NaN           NaN          NaN
# Earth house                     1.0         NaN           NaN          NaN
# Farm stay                       1.0         NaN           1.0          NaN
# Guest suite                    25.0         NaN          20.0          1.0
# Guesthouse                     38.0         NaN          52.0          3.0
# Hostel                          NaN        35.0          14.0         23.0
# Hotel                           NaN       122.0         115.0          NaN
# House                         370.0         NaN         110.0          2.0
# Houseboat                       8.0         NaN           5.0          NaN
# Igloo                           NaN         NaN           NaN          1.0
# Island                          1.0         NaN           NaN          NaN
# Loft                         1109.0         NaN          93.0          7.0
# Nature lodge                    NaN         NaN           1.0          NaN
# Other                          56.0         NaN          47.0          1.0
# Serviced apartment            225.0       198.0          17.0          1.0
# Tiny house                     21.0         NaN           5.0          4.0
# Townhouse                     168.0         NaN          79.0          2.0
# Villa                          17.0         NaN           2.0          NaN

# %%
fig, ax = plt.subplots(figsize=(18,12).plot(kind='barh',stacked=True,ax=ax)
plt.ylabel('Property type', fontsize=18)
plt.xlabel('Number of listing', fontsize=18)
ax.set_title('Property type in paris', fontsize=20,color='Green')  
plt.show()

# %%
accomodation_listings = listings[['id','accommodates']].groupby('id').mean().round().sort_values(by='id', ascending= True)
accomodation_listings.head()
# Out:
#       accommodates
# id
# 3109             2
# 5396             2
# 7397             4
# 7964             2
# 9359             2

# %%
fig, ax = plt.subplots(figsize=(18,12))
plt.ylabel('Number of listings', fontsize=18)
plt.xlabel('Accomodates', fontsize=18)
accomodation_listings.hist(ax=ax)
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x0000023BE0F7C470>],
#       dtype=object)

# %%
#Getting  price and accomodation
person_accomodationdf = pd.DataFrame({'accommodates':listings['accommodates'],'price':listings['price'],'id':listings['id']})
person_accomodationdf.head()
# Out:
#    accommodates    price    id
# 0             2   $60.00  3109
# 1             2  $115.00  5396
# 2             4  $119.00  7397
# 3             2  $130.00  7964
# 4             2   $75.00  9359

# %%
#2 person accomodation
accommodates = [2]
acc=person_accomodationdf[person_accomodationdf.accommodates.isin(accommodates)]
acc.head()
# Out:
#    accommodates    price    id
# 0             2   $60.00  3109
# 1             2  $115.00  5396
# 3             2  $130.00  7964
# 4             2   $75.00  9359
# 5             2   $75.00  9952

# %%
#Convert price to float type
acc['price']=acc['price'].str.replace(',', '').str.replace('$', '').astype(float)
acc.head()
# Out:
# C:\Users\ABONIA\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
#    accommodates  price    id
# 0             2   60.0  3109
# 1             2  115.0  5396
# 3             2  130.0  7964
# 4             2   75.0  9359
# 5             2   75.0  9952

# %%
#Get price between 0 and 140 to plot
price=acc['price'].between(0, 140.00, inclusive=False)
price.shape
# Out:
# (32319,)

# %%
#Insert the price selected between 0 and 140
price_140=acc[price]
price_140
# Out:
#        accommodates  price        id
# 0                 2   60.0      3109
# 1                 2  115.0      5396
# 3                 2  130.0      7964
# 4                 2   75.0      9359
# 5                 2   75.0      9952
# 9                 2   75.0     11170
# 11                2  100.0     11265
# 14                2   60.0     12268
# 16                2   49.0     12887
# 17                2  110.0     14264
# 18                2   75.0     14757
# 20                2   78.0     16457
# 27                2   85.0     18993
# 28                2   49.0     19029
# 34                2   55.0     21167
# 38                2  120.0     21419
# 39                2   63.0     21860
# 40                2  110.0     22158
# 41                2   70.0     22979
# 43                2   76.0     24260
# 46                2   49.0     26567
# 47                2   80.0     26827
# 48                2   50.0     27008
# 52                2   80.0     31435
# 55                2  128.0     32082
# 56                2  114.0     33004
# 57                2   88.0     33114
# 58                2   65.0     33210
# 62                2  132.0     35065
# 65                2   32.0     36490
# ...             ...    ...       ...
# 66354             2  100.0  42289284
# 66355             2   75.0  42289395
# 66356             2   87.0  42289829
# 66359             2   98.0  42290409
# 66360             2   85.0  42290435
# 66362             2   74.0  42291247
# 66364             2  100.0  42291651
# 66370             2   70.0  42295412
# 66373             2   95.0  42299730
# 66382             2   90.0  42304957
# 66384             2   36.0  42305332
# 66385             2   50.0  42306149
# 66386             2   60.0  42306170
# 66387             2   59.0  42306260
# 66388             2   98.0  42306354
# 66389             2  104.0  42306553
# 66392             2   59.0  42306985
# 66394             2   47.0  42308684
# 66395             2  100.0  42309066
# 66396             2  110.0  42309289
# 66398             2   60.0  42309792
# 66400             2   50.0  42310595
# 66401             2   50.0  42310912
# 66402             2   70.0  42310923
# 66405             2   95.0  42311552
# 66406             2   70.0  42311913
# 66407             2   62.0  42312007
# 66408             2   69.0  42312134
# 66410             2   74.0  42313047
# 66413             2   60.0  42314265
#
# [29633 rows x 3 columns]

# %%
#Convert dollar to euro
price_140['price']=price_140['price']/1.08
price_140
# Out:
# C:\Users\ABONIA\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
#        accommodates       price        id
# 0                 2   55.555556      3109
# 1                 2  106.481481      5396
# 3                 2  120.370370      7964
# 4                 2   69.444444      9359
# 5                 2   69.444444      9952
# 9                 2   69.444444     11170
# 11                2   92.592593     11265
# 14                2   55.555556     12268
# 16                2   45.370370     12887
# 17                2  101.851852     14264
# 18                2   69.444444     14757
# 20                2   72.222222     16457
# 27                2   78.703704     18993
# 28                2   45.370370     19029
# 34                2   50.925926     21167
# 38                2  111.111111     21419
# 39                2   58.333333     21860
# 40                2  101.851852     22158
# 41                2   64.814815     22979
# 43                2   70.370370     24260
# 46                2   45.370370     26567
# 47                2   74.074074     26827
# 48                2   46.296296     27008
# 52                2   74.074074     31435
# 55                2  118.518519     32082
# 56                2  105.555556     33004
# 57                2   81.481481     33114
# 58                2   60.185185     33210
# 62                2  122.222222     35065
# 65                2   29.629630     36490
# ...             ...         ...       ...
# 66354             2   92.592593  42289284
# 66355             2   69.444444  42289395
# 66356             2   80.555556  42289829
# 66359             2   90.740741  42290409
# 66360             2   78.703704  42290435
# 66362             2   68.518519  42291247
# 66364             2   92.592593  42291651
# 66370             2   64.814815  42295412
# 66373             2   87.962963  42299730
# 66382             2   83.333333  42304957
# 66384             2   33.333333  42305332
# 66385             2   46.296296  42306149
# 66386             2   55.555556  42306170
# 66387             2   54.629630  42306260
# 66388             2   90.740741  42306354
# 66389             2   96.296296  42306553
# 66392             2   54.629630  42306985
# 66394             2   43.518519  42308684
# 66395             2   92.592593  42309066
# 66396             2  101.851852  42309289
# 66398             2   55.555556  42309792
# 66400             2   46.296296  42310595
# 66401             2   46.296296  42310912
# 66402             2   64.814815  42310923
# 66405             2   87.962963  42311552
# 66406             2   64.814815  42311913
# 66407             2   57.407407  42312007
# 66408             2   63.888889  42312134
# 66410             2   68.518519  42313047
# 66413             2   55.555556  42314265
#
# [29633 rows x 3 columns]

# %%
#Get average price
price_person = price_140[['accommodates','price','id']].groupby('price').mean().round().sort_values(by='id', ascending=False)
price_person.reset_index(0, inplace=True)
price_person.shape
# Out:
# (131, 3)

# %%
#Plot 2 person accomodation vs price
plt.figure(figsize=(18,20))
sns.barplot(x=price_person['price'], y=price_person['id'],orient="h")
plt.xlabel('Average daily price-Euro', fontsize=15)
plt.ylabel('ID', fontsize=15)
plt.title("Average daily price for 2-persons accomodation", fontsize=20)
plt.xticks(rotation= 90)
plt.tight_layout()

# %%
reviews=pd.read_csv("C:/Users/ABONIA/Downloads/reviews.csv")
reviews.head()
# Out:
#    listing_id        date
# 0        3109  2016-12-27
# 1        3109  2016-12-28
# 2        3109  2017-10-28
# 3        3109  2017-11-03
# 4        3109  2018-02-12

# %%
calendar = pd.read_csv('C:/Users/ABONIA/Downloads/calendar.csv.gz', compression='gzip', header=0, sep=' ', quotechar='"', error_bad_lines=False)
calendar.head()
# Out:
#   listing_id,date,available,price,adjusted_price,minimum_nights,maximum_nights
# 0            63873,2020-02-16,f,$320.00,$320.00,3,60
# 1              19029,2020-02-16,f,$55.00,$55.00,7,15
# 2              19029,2020-02-17,f,$55.00,$55.00,7,15
# 3              19029,2020-02-18,f,$55.00,$55.00,7,15
# 4              19029,2020-02-19,f,$55.00,$55.00,7,15

# %%
listings.columns.tolist()
# Out:
# ['id',
#  'listing_url',
#  'scrape_id',
#  'last_scraped',
#  'name',
#  'summary',
#  'space',
#  'description',
#  'experiences_offered',
#  'neighborhood_overview',
#  'notes',
#  'transit',
#  'access',
#  'interaction',
#  'house_rules',
#  'thumbnail_url',
#  'medium_url',
#  'picture_url',
#  'xl_picture_url',
#  'host_id',
#  'host_url',
#  'host_name',
#  'host_since',
#  'host_location',
#  'host_about',
#  'host_response_time',
#  'host_response_rate',
#  'host_acceptance_rate',
#  'host_is_superhost',
#  'host_thumbnail_url',
#  'host_picture_url',
#  'host_neighbourhood',
#  'host_listings_count',
#  'host_total_listings_count',
#  'host_verifications',
#  'host_has_profile_pic',
#  'host_identity_verified',
#  'street',
#  'neighbourhood',
#  'neighbourhood_cleansed',
#  'neighbourhood_group_cleansed',
#  'city',
#  'state',
#  'zipcode',
#  'market',
#  'smart_location',
#  'country_code',
#  'country',
#  'latitude',
#  'longitude',
#  'is_location_exact',
#  'property_type',
#  'room_type',
#  'accommodates',
#  'bathrooms',
#  'bedrooms',
#  'beds',
#  'bed_type',
#  'amenities',
#  'square_feet',
#  'price',
#  'weekly_price',
#  'monthly_price',
#  'security_deposit',
#  'cleaning_fee',
#  'guests_included',
#  'extra_people',
#  'minimum_nights',
#  'maximum_nights',
#  'minimum_minimum_nights',
#  'maximum_minimum_nights',
#  'minimum_maximum_nights',
#  'maximum_maximum_nights',
#  'minimum_nights_avg_ntm',
#  'maximum_nights_avg_ntm',
#  'calendar_updated',
#  'has_availability',
#  'availability_30',
#  'availability_60',
#  'availability_90',
#  'availability_365',
#  'calendar_last_scraped',
#  'number_of_reviews',
#  'number_of_reviews_ltm',
#  'first_review',
#  'last_review',
#  'review_scores_rating',
#  'review_scores_accuracy',
#  'review_scores_cleanliness',
#  'review_scores_checkin',
#  'review_scores_communication',
#  'review_scores_location',
#  'review_scores_value',
#  'requires_license',
#  'license',
#  'jurisdiction_names',
#  'instant_bookable',
#  'is_business_travel_ready',
#  'cancellation_policy',
#  'require_guest_profile_picture',
#  'require_guest_phone_verification',
#  'calculated_host_listings_count',
#  'calculated_host_listings_count_entire_homes',
#  'calculated_host_listings_count_private_rooms',
#  'calculated_host_listings_count_shared_rooms',
#  'reviews_per_month']

# %%
listings[['latitude','longitude','street','zipcode','city','state','smart_location']]
# Out:
#        latitude  longitude                                 street zipcode  \
# 0      48.83349    2.31852           Paris, Île-de-France, France   75014
# 1      48.85100    2.35869           Paris, Ile-de-France, France   75004
# 2      48.85758    2.35275           Paris, Île-de-France, France   75004
# 3      48.87417    2.34245           Paris, Île-de-France, France   75009
# 4      48.85899    2.34735           Paris, Île-de-France, France   75001
# 5      48.86227    2.37134           Paris, Ile-de-France, France   75011
# 6      48.88902    2.34656           Paris, Ile-de-France, France   75018
# 7      48.88918    2.34490           Paris, Ile-de-France, France   75018
# 8      48.87900    2.31608           Paris, Ile-de-France, France   75008
# 9      48.84670    2.35095           Paris, Île-de-France, France   75005
# 10     48.87110    2.37424           Paris, Île-de-France, France   75011
# 11     48.88434    2.34005           Paris, Île-de-France, France   75018
# 12     48.82405    2.36828           Paris, Île-de-France, France   75013
# 13     48.86578    2.37705           Paris, Ile-de-France, France   75011
# 14     48.85090    2.38695           Paris, Ile-de-France, France   75011
# 15     48.85909    2.37704           Paris, Île-de-France, France   75011
# 16     48.86189    2.37997           Paris, Île-de-France, France   75011
# 17     48.88315    2.34158           Paris, Île-de-France, France   75018
# 18     48.89052    2.34453                     Paris, IDF, France   75018
# 19     48.83616    2.36323           Paris, Ile-de-France, France   75013
# 20     48.85339    2.36284           Paris, Île-de-France, France   75004
# 21     48.85324    2.34171           Paris, Ile-de-France, France   75006
# 22     48.89566    2.38307           Paris, Île-de-France, France   75019
# 23     48.87217    2.36206           Paris, Île-de-France, France   75010
# 24     48.88282    2.33272           Paris, Île-de-France, France   75009
# 25     48.88327    2.33292           Paris, Île-de-France, France   75009
# 26     48.86185    2.34340           Paris, Ile-de-France, France   75001
# 27     48.89001    2.34584           Paris, Ile-de-France, France   75018
# 28     48.88308    2.33283           Paris, Île-de-France, France   75009
# 29     48.88565    2.35906           Paris, Ile-de-France, France   75018
# ...         ...        ...                                    ...     ...
# 66384  48.83231    2.30708                     Paris, IDF, France   75015
# 66385  48.88534    2.33569           Paris, Île-de-France, France   75018
# 66386  48.88366    2.39343           Paris, Île-de-France, France   75019
# 66387  48.85090    2.38023           Paris, Île-de-France, France   75011
# 66388  48.88266    2.33407           Paris, Île-de-France, France   75009
# 66389  48.81894    2.37940  Ivry-sur-Seine, Île-de-France, France   94200
# 66390  48.88515    2.31773           Paris, Île-de-France, France   75017
# 66391  48.89146    2.33035           Paris, Île-de-France, France   75018
# 66392  48.88288    2.36672                     Paris, IDF, France   75010
# 66393  48.83803    2.39291           Paris, Île-de-France, France   75012
# 66394  48.83925    2.34731           Paris, Île-de-France, France   75005
# 66395  48.84893    2.42038                 Vincennes, IDF, France   94300
# 66396  48.83747    2.39943           Paris, Île-de-France, France   75012
# 66397  48.84079    2.34099                     Paris, IDF, France   75005
# 66398  48.82498    2.33062                   Paris, Paris, France   75014
# 66399  48.86560    2.29748           Paris, Île-de-France, France   75116
# 66400  48.88874    2.35319           Paris, Île-de-France, France   75018
# 66401  48.87855    2.37520                     Paris, IDF, France   75019
# 66402  48.85721    2.30655           Paris, Île-de-France, France   75007
# 66403  48.89262    2.28977          Levallois-Perret, IDF, France   92300
# 66404  48.85218    2.40166           Paris, Île-de-France, France   75020
# 66405  48.88631    2.33880                     Paris, IDF, France   75018
# 66406  48.86253    2.27550           Paris, Île-de-France, France   75116
# 66407  48.88143    2.33537           Paris, Île-de-France, France   75009
# 66408  48.84353    2.28355           Paris, Île-de-France, France   75015
# 66409  48.88441    2.38440                          Paris, France   75019
# 66410  48.89057    2.34737                          Paris, France   75018
# 66411  48.88786    2.32409           Paris, Île-de-France, France   75017
# 66412  48.85445    2.31146           Paris, Île-de-France, France   75007
# 66413  48.87398    2.38206           Paris, Île-de-France, France   75019
#
#                    city          state            smart_location
# 0                 Paris  Île-de-France             Paris, France
# 1                 Paris  Ile-de-France             Paris, France
# 2                 Paris  Île-de-France             Paris, France
# 3                 Paris  Île-de-France             Paris, France
# 4                 Paris  Île-de-France             Paris, France
# 5                 Paris  Ile-de-France             Paris, France
# 6                 Paris  Ile-de-France             Paris, France
# 7                 Paris  Ile-de-France             Paris, France
# 8                 Paris  Ile-de-France             Paris, France
# 9                 Paris  Île-de-France             Paris, France
# 10                Paris  Île-de-France             Paris, France
# 11                Paris  Île-de-France             Paris, France
# 12                Paris  Île-de-France             Paris, France
# 13                Paris  Ile-de-France             Paris, France
# 14                Paris  Ile-de-France             Paris, France
# 15                Paris  Île-de-France             Paris, France
# 16                Paris  Île-de-France             Paris, France
# 17                Paris  Île-de-France             Paris, France
# 18                Paris            IDF             Paris, France
# 19                Paris  Ile-de-France             Paris, France
# 20                Paris  Île-de-France             Paris, France
# 21                Paris  Ile-de-France             Paris, France
# 22                Paris  Île-de-France             Paris, France
# 23                Paris  Île-de-France             Paris, France
# 24                Paris  Île-de-France             Paris, France
# 25                Paris  Île-de-France             Paris, France
# 26                Paris  Ile-de-France             Paris, France
# 27                Paris  Ile-de-France             Paris, France
# 28                Paris  Île-de-France             Paris, France
# 29                Paris  Ile-de-France             Paris, France
# ...                 ...            ...                       ...
# 66384             Paris            IDF             Paris, France
# 66385             Paris  Île-de-France             Paris, France
# 66386             Paris  Île-de-France             Paris, France
# 66387             Paris  Île-de-France             Paris, France
# 66388             Paris  Île-de-France             Paris, France
# 66389    Ivry-sur-Seine  Île-de-France    Ivry-sur-Seine, France
# 66390             Paris  Île-de-France             Paris, France
# 66391             Paris  Île-de-France             Paris, France
# 66392             Paris            IDF             Paris, France
# 66393             Paris  Île-de-France             Paris, France
# 66394             Paris  Île-de-France             Paris, France
# 66395         Vincennes            IDF         Vincennes, France
# 66396             Paris  Île-de-France             Paris, France
# 66397             Paris            IDF             Paris, France
# 66398             Paris          Paris             Paris, France
# 66399             Paris  Île-de-France             Paris, France
# 66400             Paris  Île-de-France             Paris, France
# 66401             Paris            IDF             Paris, France
# 66402             Paris  Île-de-France             Paris, France
# 66403  Levallois-Perret            IDF  Levallois-Perret, France
# 66404             Paris  Île-de-France             Paris, France
# 66405             Paris            IDF             Paris, France
# 66406             Paris  Île-de-France             Paris, France
# 66407             Paris  Île-de-France             Paris, France
# 66408             Paris  Île-de-France             Paris, France
# 66409             Paris            NaN             Paris, France
# 66410             Paris            NaN             Paris, France
# 66411             Paris  Île-de-France             Paris, France
# 66412             Paris  Île-de-France             Paris, France
# 66413             Paris  Île-de-France             Paris, France
#
# [66414 rows x 7 columns]

# %%
#time vs listing
start_date = '2019-01'
end_date = '2019-12'
mask = (reviews['date'] > start_date) & (reviews['date'] <= end_date)


df = reviews.loc[mask]
df['Date'] = pd.to_datetime(df["date"])

df=df[df['Date'].dt.month.isin([1,5, 7,9,10])]

#type_df = review.groupby('listing_id').id.count()
type_df =df[['listing_id','Date']].groupby('Date').count()
type_df.reset_index(0, inplace=True)
#type_df = type_df.reset_index()
#type_df = type_df.rename(columns={'date': 'number_of_listings'})
type_df
# Out:
# C:\Users\ABONIA\Anaconda3\lib\site-packages\ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#           Date  listing_id
# 0   2019-01-01        2070
# 1   2019-01-02        1880
# 2   2019-01-03        1337
# 3   2019-01-04        1227
# 4   2019-01-05        1130
# 5   2019-01-06        1213
# 6   2019-01-07         631
# 7   2019-01-08         499
# 8   2019-01-09         482
# 9   2019-01-10         551
# 10  2019-01-11         622
# 11  2019-01-12         554
# 12  2019-01-13        1125
# 13  2019-01-14         630
# 14  2019-01-15         493
# 15  2019-01-16         509
# 16  2019-01-17         555
# 17  2019-01-18         782
# 18  2019-01-19         628
# 19  2019-01-20        1571
# 20  2019-01-21        1071
# 21  2019-01-22         820
# 22  2019-01-23         762
# 23  2019-01-24         797
# 24  2019-01-25         833
# 25  2019-01-26         686
# 26  2019-01-27        1486
# 27  2019-01-28         764
# 28  2019-01-29         501
# 29  2019-01-30         524
# ..         ...         ...
# 124 2019-10-02        1440
# 125 2019-10-03        1437
# 126 2019-10-04        1608
# 127 2019-10-05        1364
# 128 2019-10-06        2527
# 129 2019-10-07        1594
# 130 2019-10-08        1337
# 131 2019-10-09        1222
# 132 2019-10-10        1409
# 133 2019-10-11        1538
# 134 2019-10-12        1287
# 135 2019-10-13        2432
# 136 2019-10-14        1533
# 137 2019-10-15        1386
# 138 2019-10-16        1383
# 139 2019-10-17        1540
# 140 2019-10-18        1486
# 141 2019-10-19        1141
# 142 2019-10-20        2153
# 143 2019-10-21        1423
# 144 2019-10-22        1250
# 145 2019-10-23        1315
# 146 2019-10-24        1427
# 147 2019-10-25        1539
# 148 2019-10-26        1276
# 149 2019-10-27        2211
# 150 2019-10-28        1419
# 151 2019-10-29        1157
# 152 2019-10-30        1274
# 153 2019-10-31        1407
#
# [154 rows x 2 columns]

# %%
from matplotlib.dates import MonthLocator, DateFormatter
plt.plot(type_df['Date'],type_df['listing_id'])

ax = plt.gca()


mnt = MonthLocator(bymonthday=1, interval=2)
mnt_fmt = DateFormatter("%b '%y")
ax.xaxis.set_major_locator(mnt)
ax.xaxis.set_major_formatter(mnt_fmt)

ax.grid( linestyle='-', linewidth=1)
#ax.grid(color='r', linestyle='-', linewidth=2)

plt.ylabel('Number of listings available', fontsize=18)
plt.xlabel('Date', fontsize=18)
ax.set_title('Number of listings available by date', fontsize=20)
ax.figure.set_size_inches(20, 10)

plt.show()

# %%
#Get price
price = pd.DataFrame({'price':listings['price'],'id':listings['id']})
price.head()
#Convert price to float type
price['price']=price['price'].str.replace(',', '').str.replace('$', '').astype(float)
price.head()
#Get price between 0 and 140 to plot
priceC=price['price'].between(120, 240.00, inclusive=False)
priceC.shape
#Insert the price selected between 0 and 140
price_240=price[priceC]
price_240
#Convert dollar to euro
price_240['price']=price_240['price']/1.08
price_240
# Out:
# C:\Users\ABONIA\Anaconda3\lib\site-packages\ipykernel_launcher.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#             price        id
# 3      120.370370      7964
# 10     145.370370     11213
# 23     138.888889     17316
# 32     120.370370     20823
# 33     185.185185     21004
# 49     115.740741     27288
# 55     118.518519     32082
# 59     138.888889     33814
# 62     122.222222     35065
# 68     138.888889     37010
# 75     128.703704     40143
# 81     162.037037     41106
# 84     138.888889     43027
# 86     143.518519     43500
# 87     166.666667     44123
# 88     138.888889     44130
# 92     120.370370     47155
# 93     162.037037     48498
# 94     152.777778     48584
# 95     175.925926     48592
# 100    148.148148     53353
# 101    120.370370     53734
# 107    138.888889     56662
# 110    138.888889     58099
# 120    157.407407     63480
# 125    128.703704     70586
# 130    125.000000     73533
# 137    152.777778     79690
# 140    134.259259     81033
# 145    115.740741     85145
# ...           ...       ...
# 66247  184.259259  42238413
# 66250  138.888889  42240636
# 66253  148.148148  42241956
# 66256  120.370370  42242462
# 66260  138.888889  42243072
# 66261  125.000000  42243170
# 66262  142.592593  42243189
# 66266  135.185185  42244493
# 66271  143.518519  42245290
# 66276  119.444444  42248388
# 66285  120.370370  42250374
# 66298  113.888889  42261610
# 66301  212.962963  42262164
# 66307  184.259259  42263524
# 66313  166.666667  42266062
# 66317  134.259259  42267980
# 66321  125.000000  42268938
# 66328  162.037037  42272224
# 66338  203.703704  42277385
# 66348  138.888889  42287131
# 66357  157.407407  42289862
# 66365  171.296296  42291802
# 66371  138.888889  42295995
# 66379  185.185185  42304170
# 66381  157.407407  42304817
# 66391  175.925926  42306893
# 66393  162.037037  42307526
# 66397  138.888889  42309662
# 66411  137.962963  42313051
# 66412  137.962963  42313747
#
# [11524 rows x 2 columns]

# %%
type_df.head()
# Out:
#         Date  listing_id
# 0 2019-01-01        2070
# 1 2019-01-02        1880
# 2 2019-01-03        1337
# 3 2019-01-04        1227
# 4 2019-01-05        1130

# %%
mergeLR=pd.concat([price_240, type_df],axis=1)
mergeLR.tail()
# Out:
#             price          id Date  listing_id
# 66391  175.925926  42306893.0  NaT         NaN
# 66393  162.037037  42307526.0  NaT         NaN
# 66397  138.888889  42309662.0  NaT         NaN
# 66411  137.962963  42313051.0  NaT         NaN
# 66412  137.962963  42313747.0  NaT         NaN

# %%
mergeLR=pd.merge(price_240, type_df.rename(columns={'listing_id':'id'}), on='id',how='right')
mergeLR
# Out:
#      price    id       Date
# 149    NaN  1276 2019-10-26
# 150    NaN  2211 2019-10-27
# 151    NaN  1419 2019-10-28
# 152    NaN  1157 2019-10-29
# 153    NaN  1274 2019-10-30

# %%
price_240['price'] = price_240.id.map(type_df.set_index('listing_id')['Date'])
print (price_240)
# Out:
# ---------------------------------------------------------------------------
# InvalidIndexError                         Traceback (most recent call last)
# <ipython-input-412-e614734f7174> in <module>()
# ----> 1 price_240['price'] = price_240.id.map(type_df.set_index('listing_id')['Date'])
#       2 print (price_240)
#
# ~\Anaconda3\lib\site-packages\pandas\core\series.py in map(self, arg, na_action)
#    3380         """
#    3381         new_values = super(Series, self)._map_values(
# -> 3382             arg, na_action=na_action)
#    3383         return self._constructor(new_values,
#    3384                                  index=self.index).__finalize__(self)
#
# ~\Anaconda3\lib\site-packages\pandas\core\base.py in _map_values(self, mapper, na_action)
#    1194                 values = self.values
#    1195
# -> 1196             indexer = mapper.index.get_indexer(values)
#    1197             new_values = algorithms.take_1d(mapper._values, indexer)
#    1198
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_indexer(self, target, method, limit, tolerance)
#    2683
#    2684         if not self.is_unique:
# -> 2685             raise InvalidIndexError('Reindexing only valid with uniquely'
#    2686                                     ' valued Index objects')
#    2687
#
# InvalidIndexError: Reindexing only valid with uniquely valued Index objects

# %%
#time vs listing
start_date = '2019-01'
end_date = '2019-12'
mask = (reviews['date'] > start_date) & (reviews['date'] <= end_date)


df = reviews.loc[mask]
df['Date'] = pd.to_datetime(df["date"])

df=df[df['Date'].dt.month.isin([1,5, 7,9,10])]

#type_df = review.groupby('listing_id').id.count()
type_df =df[['listing_id','Date']].groupby('Date').count()
type_df.reset_index(0, inplace=True)
#type_df = type_df.reset_index()
#type_df = type_df.rename(columns={'date': 'number_of_listings'})
type_df

# %%
from matplotlib.dates import MonthLocator, DateFormatter
plt.plot(type_df['Date'],type_df['Price'])

ax = plt.gca()

mnt = MonthLocator(bymonthday=1, interval=2)
mnt_fmt = DateFormatter("%b '%y")
ax.xaxis.set_major_locator(mnt)
ax.xaxis.set_major_formatter(mnt_fmt)

plt.ylabel('Number of listings available', fontsize=18)
plt.xlabel('Date', fontsize=18)
ax.set_title('Number of listings available by date', fontsize=20)
plt.figure(figsize=(20,10))
plt.show()
